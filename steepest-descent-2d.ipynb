# %%
# Library imports
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import scipy.optimize as optimize
import sympy as sp
from matplotlib import cm

# %%
# Source under probe
FreqHz = 1e6 # Fundamental frequency of simulation
Tperiod = 1 / FreqHz # Fundamental time period of simulation
Nsamp = int(1e6) # Number of samples
t = np.arange(Nsamp, dtype=float) * Tperiod # Time series: (0...Nsamp) * Time period

Tr = Tperiod * 100000 # Time period of motion we are trying to measure: 100 x sampling time period
Omega = 0.5 * np.pi / Tr # Omega of motion
xr = 25 * np.cos(Omega * t) # + 20 * np.cos(2 * Omega * t + 2) + 15 * np.sin(5 * Omega * t + 0.7) + 5 * np.sin(10 * Omega * t + 1.2) # X position of motion, let's say it's a sinusoid with amplitude 100 (degrees)
yr = 75 * np.sin(Omega * t)

# %%
# Let's see what the motion looks like
plt.figure()
plt.plot(t, xr, c = 'k', label = 'Real motion X')
plt.plot(t, yr, c = 'r', label = 'Real motion Y')
plt.xlabel('Time (s)')
plt.ylabel('Position (Deg)')
plt.grid()
plt.legend()
plt.show()

# %%
# This is for 1D Beam
gridMax = 100
xx = np.linspace(-gridMax, gridMax, 5 * gridMax + 1, endpoint = True) # 0.04 grid spacing
yy = np.linspace(-gridMax, gridMax, 5 * gridMax + 1, endpoint = True) # 0.04 grid spacing

xg, yg = np.meshgrid(xx, yy)

xyg = [xg, yg]

# Define 1D Gaussian, which is our beam
def gauss2D(coord, m, s):
    return np.exp(-0.5 * ((coord[0] - m[0]) * (coord[0] - m[0]) + (coord[1] - m[1]) * (coord[1] - m[1])) / (s * s))

# %%
# Test Gaussian
plt.imshow(10 * gauss2D(xyg.copy(), [xr[70000], yr[70000]], 20), origin = 'lower', extent = (-gridMax, gridMax, -gridMax, gridMax))
plt.colorbar()
plt.grid()
plt.show()

# %%
# Animation of the beam
from IPython.display import HTML
from matplotlib import animation
fskip = 1000
fig = plt.figure(figsize = (10, 6))
extent = [0, 5 * gridMax + 1, 0, 5 * gridMax + 1]
im = plt.imshow(np.zeros((5 * gridMax + 1, 5 * gridMax + 1),dtype=float),origin='lower',vmin=0,vmax=1,animated=True,cmap='bone',extent=extent)

def animate(i):
    i *= fskip # every 1000th step (ms)
    im.set_array(gauss2D(xyg, [xr[i], yr[i]], 15))
    return im,

anim = animation.FuncAnimation(fig, animate, frames = xr.shape[0] // fskip, interval = 17, blit = True)
HTML(anim.to_html5_video()) # requires ffmpeg, install using `conda install ffmpeg`
# Out:
# <video width="720" height="432" controls autoplay loop>
#   <source type="video/mp4" src="...

# %%
from IPython.display import HTML
from matplotlib import animation

fig = plt.figure(figsize = (10, 6))
ax = plt.axes(xlim=(0, 5 * gridMax + 1), ylim=(0, 5 * gridMax + 1))
fig.suptitle('Time: %d milliseconds' % (0))
plt.grid()
line, = ax.plot([], [], lw=2, c = 'b', label = 'Beam')
fskip = 1000 # one frame per 16 milisecond

lx = []
ly = []

def init():
    line.set_data(lx, ly)
    plt.legend()
    return line, # return a tuple

def animate(fid):
    tid = (fid * fskip) % xr.shape[0] # Time ID: frame ID * frame skip, the modulo keeps it from exceeding array size
    fig.suptitle('Time: %d milliseconds' % (1e3 * t[tid]))
    # y = 10 * gauss1D(xx, xr[tid], 15) # beam at tid, which is index of time (time = tid * Tperiod)
    lx.append((np.abs(xx - xr[tid])).argmin())
    ly.append((np.abs(yy - yr[tid])).argmin())
    line.set_data(lx, ly) # plot X and Y
#     ax.axvline(xr[tid], c = 'r', label = 'Center of beam')
    return line,

anim = animation.FuncAnimation(fig, animate, init_func = init, frames = xr.shape[0] // fskip, interval = 17, blit = True)
HTML(anim.to_html5_video()) # requires ffmpeg, install using `conda install ffmpeg`
# Out:
# <video width="720" height="432" controls autoplay loop>
#   <source type="video/mp4" src="...

# %%
# This is for 2D Beam

# # Now we generate our beam, which is a Gaussian in 2D space around the X coordinate
# gridMax = 100
# xx = np.linspace(-gridMax, gridMax, 5 * gridMax + 1, endpoint = True) # 0.04 grid spacing
# yy = xx # square grid so make an alias
# (xp, yp) = np.meshgrid(xx, yy) # generate X-Y plane

# # Define 2D Gaussian:
# def gauss2D(xx, yy, mx, my, s):
#     xx_ = xx - mx # Recenter X
#     yy_ = yy - my # Recenter Y
#     dist = (xx_*xx_ + yy_*yy_) # calculate Euclidean distance on 2D plane
#     return np.exp(-0.5 * dist / (s * s)) # Gaussian: exp(-x^2/2s^2)

# # Test Gaussian
# plt.figure(figsize=(6,6))
# gaussval = gauss2D(xp, yp, 20, 30, 15) # beam at (20, 30), width 15
# plt.imshow(gaussval, extent = [-gridMax, gridMax, -gridMax, gridMax])
# plt.grid()
# plt.show()
    
# # now to generate the REAL beam position with time, we need to
# # generate a 3D array of the position of these 

# sigr = np.array([gauss2D(xp, yp, mx, 0, 10) for mx in xr]) # beam from source, width 10

# %% [markdown]
# ## Steepest Descent
# Note that, the actual beam is spread in space at every moment in time.
# However, at any moment in time we can only sample one point in space (or average of a small area in space).
# A-priori information is the peak of the beam at $t = 0$.
# At subsequent points in time, as the peak of the beam moves about, we need to find it.
#
# #### At any point of time, you can ONLY sample one point in space or the average of a small area in space.

# %%
# generate the gaussian signal
def generate_sig(step, width):
    return gauss2D(xyg, [xr[step], yr[step]], width)

# measure the signal with a Gaussian uncertainty of 5% (signal strength 1)
def measure_sig(step, posx, posy, width):
    # sig = generate_sig(step, width)[posx, posy]
    # Optimize this:
    _x = (xx[posx] - xr[step]) / width
    _y = (yy[posy] - yr[step]) / width
    sig = np.exp(-0.5*(_x * _x + _y * _y))
#     return sig + (np.random.random()-0.5) * 0.01 # 0.5% uncertainty in signal measurement
    return np.abs(sig + (np.random.random()-0.5) * 0.1) # 5% uncertainty in signal measurement
"""
istep: Time index in the beginning
istop: Time index to end at
width: Beam width
dt   : Number of time steps between two steps of the steepest descent loop
alpha: Gain for the time derivative in the steepest descent
beta : Gain for the space derivative in the steepest descent
"""
def track_max(istep, istop, width, dt, alpha, beta):
    sigtrack_arr = []
    xtrack_arr = []
    print(np.where(generate_sig(istep, width)==generate_sig(istep, width).max()))
    guess_i_x = np.where(generate_sig(istep, width)==generate_sig(istep, width).max())[1][0] # at t = 0, this is where the emitter is
#     guess_i_x = (np.abs(xx - xr[istep])).argmin()
    print(guess_i_x)
    
    guess_i_y = np.where(generate_sig(istep, width)==generate_sig(istep, width).max())[0][0] # at t = 0, this is where the emitter is
#     guess_i_y = (np.abs(yy - yr[istep])).argmin()
    print(guess_i_y)
    
    xtrack_arr.append([guess_i_x, guess_i_y])
    
    msig = measure_sig(istep, guess_i_x, guess_i_y, width) # initial signal measurement
    print("Step: %d, Movement, signal: %.3e %.3e %.3e"%(istep, 0, 0, msig))
    sigtrack_arr.append(msig)
    xtrack_arr.append([guess_i_x, guess_i_y])
    
    msig2 = measure_sig(istep + dt, guess_i_x, guess_i_y, width) # second guess
    print("Step: %d, Movement, signal: %.3e %.3e %.3e"%(istep + dt, 0, 0, msig2))
    sigtrack_arr.append(msig2)
    tderivative = (msig2 - msig) * FreqHz / dt # partial time derivative of signal
    xderivative = 0
    yderivative = 0
#     alpha = (1/Nsamp) * 200 # learning rate for time (0.5% uncertainty)
#     beta = 400 # learning rate for space(0.5% uncertainty)
    # alpha = (dt/Nsamp) * 50 # learning rate for time
    alpha *= dt/Nsamp # setting the unit
    # beta = 50 # learning rate for space
    istop = istop if istop < Nsamp else Nsamp
    atX = True
    for i in range(istep + 2 * dt, istop, dt): # steps in T
        msig = msig2 # save the old measurement
        dx = 0
        dy = 0
        if not atX: # odd case, Y
            guess_i_x2 = guess_i_x
            dy = alpha * tderivative - beta[1] * yderivative
            yguess_i = int(guess_i_y - dy) # new guess     
            if (yguess_i >= 0 and yguess_i < yy.shape[0]): # not OOB
                guess_i_y2 = yguess_i # update the guess
            else:
                guess_i_y2 = guess_i_y # keep the old guess
        else: # even case, X
            guess_i_y2 = guess_i_y
            dx = alpha * tderivative - beta[0] * xderivative
            xguess_i = int(guess_i_x - dx) # new guess
            if (xguess_i >= 0 and xguess_i < xx.shape[0]): # not OOB
                guess_i_x2 = xguess_i # update the guess
            else:
                guess_i_x2 = guess_i_x # keep the old guess        
            
        msig2 = measure_sig(i, guess_i_x2, guess_i_y2, width) # new measurement at new/old position
        if not (i % 1000):
            print("Step: %d, Movement, signal: %.3e %.3e %.3e"%(i, dx, dy, msig2))
        
        tderivative = (msig2 - msig) * FreqHz / dt # partial time derivative of signal
        
        if not atX: # odd case, Y
            if (guess_i_y2 == guess_i_y): # if we did not change position
                yderivative = 0 # x partial derivative is zero
            else:
                yderivative = (msig2 - msig) / (guess_i_y2 - guess_i_y) # partial spatial derivative of signal
        else:
            if (guess_i_x2 == guess_i_x): # if we did not change position
                xderivative = 0 # x partial derivative is zero
            else:
                xderivative = (msig2 - msig) / (guess_i_x2 - guess_i_x) # partial spatial derivative of signal
            
            
        sigtrack_arr.append(msig) # append new signal
        
        xtrack_arr.append([guess_i_x2, guess_i_y2]) # append new position
        
        guess_i_x = guess_i_x2 # update old position with new
        
        guess_i_y = guess_i_y2 # update old position with new
        
        atX = not atX
        
    return (np.array(xtrack_arr, dtype = int), np.array(sigtrack_arr, dtype = float))

# %%
# Track from t = 0, beam width 15, perform measurement at every timestep (not ideal), learning rates alpha, beta = 50
istart = 0
istop = 400000
istep = 1
bwidth = 15
# alpha and beta parameters are found with trial and error
xtrack_arr, sigtrack_arr = track_max(istart, istop, bwidth, istep, 10, [65, 65])
# Out:
# (array([250, 250]), array([312, 313]))
# 312
# 250
# Step: 0, Movement, signal: 0.000e+00 0.000e+00 1.013e+00
# Step: 1, Movement, signal: 0.000e+00 0.000e+00 9.754e-01
# Step: 1000, Movement, signal: -3.375e+00 0.000e+00 9.794e-01
# Step: 2000, Movement, signal: 1.500e+00 0.000e+00 9.561e-01
# Step: 3000, Movement, signal: -4.250e+00 0.000e+00 9.810e-01
# Step: 4000, Movement, signal: -6.015e-01 0.000e+00 9.148e-01
# Step: 5000, Movement, signal: -5.427e-02 0.000e+00 8.459e-01
# Step: 6000, Movement, signal: -1.160e-01 0.000e+00 1.032e+00
# Step: 7000, Movement, signal: -3.421e+00 0.000e+00 8.401e-01
# Step: 8000, Movement, signal: -7.038e-01 0.000e+00 9.494e-01
# Step: 9000, Movement, signal: -1.878e+00 0.000e+00 7.429e-01
# Step: 10000, Movement, signal: -7.554e-01 0.000e+00 9.608e-01
# Step: 11000, Movement, signal: -2.096e-01 0.000e+00 9.412e-01
# Step: 12000, Movement, signal: -3.675e+00 0.000e+00 9.870e-01
# Step: 13000, Movement, signal: -2.248e+00 0.000e+00 9.520e-01
# Step: 14000, Movement, signal: 1.056e+00 0.000e+00 8.864e-01
# Step: 15000, Movement, signal: 6.253e-01 0.000e+00 9.190e-01
# Step: 16000, Movement, signal: -1.822e-01 0.000e+00 9.830e-01
# Step: 17000, Movement, signal: -1.398e-01 0.000e+00 9.064e-01
# Step: 18000, Movement, signal: 1.128e+00 0.000e+00 9.867e-01
# Step: 19000, Movement, signal: 1.909e-02 0.000e+00 1.015e+00
# Step: 20000, Movement, signal: 7.685e-02 0.000e+00 9.454e-01
# Step: 21000, Movement, signal: 1.448e+00 0.000e+00 9.388e-01
# Step: 22000, Movement, signal: 2.980e-02 0.000e+00 9.330e-01
# Step: 23000, Movement, signal: 5.046e-02 0.000e+00 9.097e-01
# Step: 24000, Movement, signal: -1.594e+00 0.000e+00 8.980e-01
# Step: 25000, Movement, signal: 5.207e-01 0.000e+00 9.000e-01
# Step: 26000, Movement, signal: -1.231e+00 0.000e+00 9.948e-01
# Step: 27000, Movement, signal: -1.265e+00 0.000e+00 9.894e-01
# Step: 28000, Movement, signal: 3.876e+00 0.000e+00 8.715e-01
# Step: 29000, Movement, signal: -3.480e-02 0.000e+00 8.520e-01
# Step: 30000, Movement, signal: 1.712e-01 0.000e+00 1.001e+00
# Step: 31000, Movement, signal: -2.835e-01 0.000e+00 9.586e-01
# Step: 32000, Movement, signal: -3.456e+00 0.000e+00 9.413e-01
# Step: 33000, Movement, signal: -8.650e-02 0.000e+00 1.009e+00
# Step: 34000, Movement, signal: -6.800e-02 0.000e+00 9.930e-01
# Step: 35000, Movement, signal: -2.966e-01 0.000e+00 9.472e-01
# Step: 36000, Movement, signal: -1.593e+00 0.000e+00 9.003e-01
# Step: 37000, Movement, signal: -5.190e+00 0.000e+00 1.018e+00
# Step: 38000, Movement, signal: 6.929e-01 0.000e+00 9.712e-01
# Step: 39000, Movement, signal: -7.816e-01 0.000e+00 9.450e-01
# Step: 40000, Movement, signal: 2.902e+00 0.000e+00 8.238e-01
# Step: 41000, Movement, signal: -1.069e-01 0.000e+00 1.029e+00
# Step: 42000, Movement, signal: -1.969e+00 0.000e+00 9.883e-01
# Step: 43000, Movement, signal: -8.201e-01 0.000e+00 7.768e-01
# Step: 44000, Movement, signal: -1.187e+00 0.000e+00 9.466e-01
# Step: 45000, Movement, signal: -1.943e-01 0.000e+00 1.008e+00
# Step: 46000, Movement, signal: 5.206e-01 0.000e+00 9.650e-01
# Step: 47000, Movement, signal: -3.405e+00 0.000e+00 9.518e-01
# Step: 48000, Movement, signal: -3.204e+00 0.000e+00 9.874e-01
# Step: 49000, Movement, signal: 2.024e-01 0.000e+00 8.357e-01
# Step: 50000, Movement, signal: 3.432e-02 0.000e+00 8.856e-01
# Step: 51000, Movement, signal: -2.440e+00 0.000e+00 9.650e-01
# Step: 52000, Movement, signal: -5.071e-01 0.000e+00 9.800e-01
# Step: 53000, Movement, signal: 1.350e+00 0.000e+00 9.828e-01
# Step: 54000, Movement, signal: -4.402e+00 0.000e+00 9.187e-01
# Step: 55000, Movement, signal: -1.105e+00 0.000e+00 9.726e-01
# Step: 56000, Movement, signal: 2.898e+00 0.000e+00 9.655e-01
# Step: 57000, Movement, signal: 1.929e-01 0.000e+00 8.331e-01
# Step: 58000, Movement, signal: 1.822e+00 0.000e+00 7.587e-01
# Step: 59000, Movement, signal: 6.702e-02 0.000e+00 8.851e-01
# Step: 60000, Movement, signal: 5.898e-01 0.000e+00 1.013e+00
# Step: 61000, Movement, signal: -2.439e-01 0.000e+00 9.971e-01
# Step: 62000, Movement, signal: -4.926e-01 0.000e+00 9.106e-01
# Step: 63000, Movement, signal: -1.639e+00 0.000e+00 8.797e-01
# Step: 64000, Movement, signal: 5.004e-01 0.000e+00 8.152e-01
# Step: 65000, Movement, signal: -4.240e+00 0.000e+00 8.964e-01
# Step: 66000, Movement, signal: -3.838e-01 0.000e+00 1.016e+00
# Step: 67000, Movement, signal: -4.640e-01 0.000e+00 9.017e-01
# Step: 68000, Movement, signal: -1.267e+00 0.000e+00 9.667e-01
# Step: 69000, Movement, signal: -2.737e+00 0.000e+00 9.575e-01
# Step: 70000, Movement, signal: 2.531e-01 0.000e+00 9.245e-01
# Step: 71000, Movement, signal: 6.723e-02 0.000e+00 9.238e-01
# Step: 72000, Movement, signal: -5.004e+00 0.000e+00 9.149e-01
# Step: 73000, Movement, signal: -9.657e-01 0.000e+00 9.486e-01
# Step: 74000, Movement, signal: 1.170e+00 0.000e+00 9.581e-01
# Step: 75000, Movement, signal: 2.787e+00 0.000e+00 9.690e-01
# Step: 76000, Movement, signal: 2.520e-01 0.000e+00 8.656e-01
# Step: 77000, Movement, signal: 3.020e-01 0.000e+00 9.146e-01
# Step: 78000, Movement, signal: -2.051e-01 0.000e+00 7.426e-01
# Step: 79000, Movement, signal: 5.473e-01 0.000e+00 1.006e+00
# Step: 80000, Movement, signal: -6.289e-01 0.000e+00 9.321e-01
# Step: 81000, Movement, signal: -2.667e+00 0.000e+00 9.787e-01
# Step: 82000, Movement, signal: -1.040e+00 0.000e+00 8.755e-01
# Step: 83000, Movement, signal: -1.176e+00 0.000e+00 8.674e-01
# Step: 84000, Movement, signal: 3.200e+00 0.000e+00 9.322e-01
# Step: 85000, Movement, signal: -5.813e-01 0.000e+00 9.874e-01
# Step: 86000, Movement, signal: -3.173e-01 0.000e+00 9.900e-01
# Step: 87000, Movement, signal: 2.132e+00 0.000e+00 9.166e-01
# Step: 88000, Movement, signal: -5.156e-01 0.000e+00 9.276e-01
# Step: 89000, Movement, signal: -2.354e-01 0.000e+00 9.571e-01
# Step: 90000, Movement, signal: 3.724e-01 0.000e+00 1.021e+00
# Step: 91000, Movement, signal: -5.263e+00 0.000e+00 9.371e-01
# Step: 92000, Movement, signal: -2.256e+00 0.000e+00 1.021e+00
# Step: 93000, Movement, signal: 2.768e+00 0.000e+00 8.109e-01
# Step: 94000, Movement, signal: -2.172e+00 0.000e+00 9.079e-01
# Step: 95000, Movement, signal: -7.089e-02 0.000e+00 9.109e-01
# Step: 96000, Movement, signal: 1.051e+00 0.000e+00 1.041e+00
# Step: 97000, Movement, signal: 1.367e+00 0.000e+00 8.795e-01
# Step: 98000, Movement, signal: -5.807e-01 0.000e+00 6.323e-01
# Step: 99000, Movement, signal: -3.640e-01 0.000e+00 9.491e-01
# Step: 100000, Movement, signal: 3.463e-01 0.000e+00 9.839e-01
# Step: 101000, Movement, signal: -1.404e+00 0.000e+00 9.244e-01
# Step: 102000, Movement, signal: 4.120e-01 0.000e+00 8.949e-01
# Step: 103000, Movement, signal: 1.541e+00 0.000e+00 9.928e-01
# Step: 104000, Movement, signal: 3.639e+00 0.000e+00 8.765e-01
# Step: 105000, Movement, signal: -2.317e-01 0.000e+00 8.897e-01
# Step: 106000, Movement, signal: -3.333e+00 0.000e+00 1.033e+00
# Step: 107000, Movement, signal: -1.018e+00 0.000e+00 9.154e-01
# Step: 108000, Movement, signal: 6.283e-01 0.000e+00 9.135e-01
# Step: 109000, Movement, signal: -1.456e+00 0.000e+00 9.690e-01
# Step: 110000, Movement, signal: -6.432e-01 0.000e+00 9.229e-01
# Step: 111000, Movement, signal: -2.776e+00 0.000e+00 9.507e-01
# Step: 112000, Movement, signal: -1.309e+00 0.000e+00 8.347e-01
# Step: 113000, Movement, signal: 4.576e-01 0.000e+00 9.384e-01
# Step: 114000, Movement, signal: -4.507e-01 0.000e+00 8.752e-01
# Step: 115000, Movement, signal: -5.760e+00 0.000e+00 9.585e-01
# Step: 116000, Movement, signal: 3.138e+00 0.000e+00 9.062e-01
# Step: 117000, Movement, signal: 5.414e-01 0.000e+00 8.179e-01
# Step: 118000, Movement, signal: -2.904e-01 0.000e+00 9.581e-01
# Step: 119000, Movement, signal: -1.620e+00 0.000e+00 9.266e-01
# Step: 120000, Movement, signal: -6.294e-02 0.000e+00 8.945e-01
# Step: 121000, Movement, signal: -2.526e-01 0.000e+00 9.708e-01
# Step: 122000, Movement, signal: -9.315e-01 0.000e+00 7.470e-01
# Step: 123000, Movement, signal: -6.409e-01 0.000e+00 9.847e-01
# Step: 124000, Movement, signal: 2.906e-01 0.000e+00 9.633e-01
# Step: 125000, Movement, signal: 5.310e+00 0.000e+00 9.124e-01
# Step: 126000, Movement, signal: 3.191e-01 0.000e+00 9.962e-01
# Step: 127000, Movement, signal: 3.248e+00 0.000e+00 8.067e-01
# Step: 128000, Movement, signal: 1.714e-01 0.000e+00 9.854e-01
# Step: 129000, Movement, signal: 4.741e-02 0.000e+00 9.835e-01
# Step: 130000, Movement, signal: -2.320e+00 0.000e+00 8.487e-01
# Step: 131000, Movement, signal: -7.930e-01 0.000e+00 8.581e-01
# Step: 132000, Movement, signal: 9.344e-03 0.000e+00 9.355e-01
# Step: 133000, Movement, signal: -6.526e-02 0.000e+00 9.604e-01
# Step: 134000, Movement, signal: 3.180e-01 0.000e+00 9.025e-01
# Step: 135000, Movement, signal: -5.315e-01 0.000e+00 9.601e-01
# Step: 136000, Movement, signal: -5.676e-01 0.000e+00 9.289e-01
# Step: 137000, Movement, signal: -6.404e-01 0.000e+00 8.476e-01
# Step: 138000, Movement, signal: 4.710e-01 0.000e+00 6.880e-01
# Step: 139000, Movement, signal: 2.481e+00 0.000e+00 9.041e-01
# Step: 140000, Movement, signal: -2.552e-01 0.000e+00 9.360e-01
# Step: 141000, Movement, signal: -1.656e+00 0.000e+00 9.291e-01
# Step: 142000, Movement, signal: 9.155e-01 0.000e+00 8.452e-01
# Step: 143000, Movement, signal: 4.620e-01 0.000e+00 9.503e-01
# Step: 144000, Movement, signal: -1.763e+00 0.000e+00 9.384e-01
# Step: 145000, Movement, signal: -1.483e+00 0.000e+00 9.587e-01
# Step: 146000, Movement, signal: -6.261e-02 0.000e+00 7.960e-01
# Step: 147000, Movement, signal: -4.739e-01 0.000e+00 9.658e-01
# Step: 148000, Movement, signal: -1.927e-01 0.000e+00 9.084e-01
# Step: 149000, Movement, signal: -1.343e+00 0.000e+00 9.943e-01
# Step: 150000, Movement, signal: -7.288e-01 0.000e+00 9.933e-01
# Step: 151000, Movement, signal: 7.131e-01 0.000e+00 8.781e-01
# Step: 152000, Movement, signal: 5.265e-02 0.000e+00 8.551e-01
# Step: 153000, Movement, signal: -2.348e+00 0.000e+00 9.122e-01
# Step: 154000, Movement, signal: 4.581e-01 0.000e+00 9.085e-01
# Step: 155000, Movement, signal: 2.325e-01 0.000e+00 7.953e-01
# Step: 156000, Movement, signal: 1.456e-01 0.000e+00 7.299e-01
# Step: 157000, Movement, signal: -2.168e-01 0.000e+00 8.465e-01
# Step: 158000, Movement, signal: -4.649e-01 0.000e+00 9.957e-01
# Step: 159000, Movement, signal: -9.080e-01 0.000e+00 9.498e-01
# Step: 160000, Movement, signal: 5.139e-01 0.000e+00 9.214e-01
# Step: 161000, Movement, signal: 8.753e-02 0.000e+00 1.025e+00
# Step: 162000, Movement, signal: -3.872e-01 0.000e+00 8.387e-01
# Step: 163000, Movement, signal: 2.586e-01 0.000e+00 8.968e-01
# Step: 164000, Movement, signal: -8.204e-01 0.000e+00 8.934e-01
# Step: 165000, Movement, signal: -1.477e-01 0.000e+00 9.075e-01
# Step: 166000, Movement, signal: -1.327e+00 0.000e+00 9.935e-01
# Step: 167000, Movement, signal: -9.238e-01 0.000e+00 9.223e-01
# Step: 168000, Movement, signal: -1.175e+00 0.000e+00 9.299e-01
# Step: 169000, Movement, signal: -4.841e+00 0.000e+00 9.675e-01
# Step: 170000, Movement, signal: 1.262e+00 0.000e+00 9.724e-01
# Step: 171000, Movement, signal: -8.039e-01 0.000e+00 7.314e-01
# Step: 172000, Movement, signal: -4.070e+00 0.000e+00 8.557e-01
# Step: 173000, Movement, signal: 2.695e+00 0.000e+00 8.734e-01
# Step: 174000, Movement, signal: -1.038e+00 0.000e+00 8.412e-01
# Step: 175000, Movement, signal: 1.686e-01 0.000e+00 9.203e-01
# Step: 176000, Movement, signal: -4.984e+00 0.000e+00 9.956e-01
# Step: 177000, Movement, signal: -4.840e-02 0.000e+00 9.917e-01
# Step: 178000, Movement, signal: 9.827e-01 0.000e+00 7.731e-01
# Step: 179000, Movement, signal: -7.422e-01 0.000e+00 9.117e-01
# Step: 180000, Movement, signal: 2.653e-01 0.000e+00 1.016e+00
# Step: 181000, Movement, signal: 3.341e+00 0.000e+00 9.588e-01
# Step: 182000, Movement, signal: 8.349e-01 0.000e+00 8.196e-01
# Step: 183000, Movement, signal: -2.125e+00 0.000e+00 9.540e-01
# Step: 184000, Movement, signal: -2.036e-01 0.000e+00 7.793e-01
# Step: 185000, Movement, signal: -2.077e+00 0.000e+00 8.479e-01
# Step: 186000, Movement, signal: 1.232e-01 0.000e+00 9.528e-01
# Step: 187000, Movement, signal: 7.590e-01 0.000e+00 9.085e-01
# Step: 188000, Movement, signal: -6.832e-01 0.000e+00 9.776e-01
# Step: 189000, Movement, signal: -5.225e+00 0.000e+00 9.631e-01
# Step: 190000, Movement, signal: -3.565e+00 0.000e+00 9.576e-01
# Step: 191000, Movement, signal: -3.828e+00 0.000e+00 8.376e-01
# Step: 192000, Movement, signal: -1.048e+00 0.000e+00 9.762e-01
# Step: 193000, Movement, signal: 2.327e+00 0.000e+00 9.300e-01
# Step: 194000, Movement, signal: 2.621e-01 0.000e+00 8.521e-01
# Step: 195000, Movement, signal: -3.193e-01 0.000e+00 8.039e-01
# Step: 196000, Movement, signal: -2.237e-01 0.000e+00 9.960e-01
# Step: 197000, Movement, signal: -7.167e-01 0.000e+00 7.917e-01
# Step: 198000, Movement, signal: -1.844e+00 0.000e+00 9.933e-01
# Step: 199000, Movement, signal: 1.331e+00 0.000e+00 9.002e-01
# Step: 200000, Movement, signal: -3.128e+00 0.000e+00 9.235e-01
# Step: 201000, Movement, signal: 6.246e-01 0.000e+00 1.011e+00
# Step: 202000, Movement, signal: 1.978e+00 0.000e+00 8.786e-01
# Step: 203000, Movement, signal: -1.666e-02 0.000e+00 9.873e-01
# Step: 204000, Movement, signal: -1.314e+00 0.000e+00 9.354e-01
# Step: 205000, Movement, signal: -1.760e+00 0.000e+00 1.012e+00
# Step: 206000, Movement, signal: -2.295e+00 0.000e+00 8.102e-01
# Step: 207000, Movement, signal: -1.611e-01 0.000e+00 9.997e-01
# Step: 208000, Movement, signal: -4.716e-01 0.000e+00 8.652e-01
# Step: 209000, Movement, signal: -1.473e+00 0.000e+00 9.204e-01
# Step: 210000, Movement, signal: -6.177e+00 0.000e+00 8.935e-01
# Step: 211000, Movement, signal: 3.733e-01 0.000e+00 7.778e-01
# Step: 212000, Movement, signal: 3.883e-01 0.000e+00 9.188e-01
# Step: 213000, Movement, signal: -2.546e-01 0.000e+00 9.749e-01
# Step: 214000, Movement, signal: 1.966e-01 0.000e+00 1.018e+00
# Step: 215000, Movement, signal: -5.735e-01 0.000e+00 1.023e+00
# Step: 216000, Movement, signal: -3.708e-01 0.000e+00 9.837e-01
# Step: 217000, Movement, signal: -1.979e+00 0.000e+00 8.673e-01
# Step: 218000, Movement, signal: 9.922e-01 0.000e+00 9.530e-01
# Step: 219000, Movement, signal: 4.705e-01 0.000e+00 8.761e-01
# Step: 220000, Movement, signal: 1.033e-01 0.000e+00 1.013e+00
# Step: 221000, Movement, signal: -7.259e-01 0.000e+00 8.800e-01
# Step: 222000, Movement, signal: -2.194e+00 0.000e+00 9.336e-01
# Step: 223000, Movement, signal: 4.334e+00 0.000e+00 7.498e-01
# Step: 224000, Movement, signal: -4.019e-01 0.000e+00 7.954e-01
# Step: 225000, Movement, signal: -1.333e+00 0.000e+00 7.513e-01
# Step: 226000, Movement, signal: 7.306e-01 0.000e+00 9.260e-01
# Step: 227000, Movement, signal: -4.940e-02 0.000e+00 7.859e-01
# Step: 228000, Movement, signal: 4.641e-01 0.000e+00 9.124e-01
# Step: 229000, Movement, signal: -4.643e-01 0.000e+00 8.932e-01
# Step: 230000, Movement, signal: -7.616e-01 0.000e+00 9.609e-01
# Step: 231000, Movement, signal: -1.436e+00 0.000e+00 7.802e-01
# Step: 232000, Movement, signal: 2.718e-01 0.000e+00 1.013e+00
# Step: 233000, Movement, signal: 8.154e-02 0.000e+00 8.677e-01
# Step: 234000, Movement, signal: -5.743e-01 0.000e+00 9.471e-01
# Step: 235000, Movement, signal: -3.970e+00 0.000e+00 9.464e-01
# Step: 236000, Movement, signal: -6.975e-01 0.000e+00 1.024e+00
# Step: 237000, Movement, signal: 3.470e-01 0.000e+00 9.149e-01
# Step: 238000, Movement, signal: -2.685e+00 0.000e+00 9.561e-01
# Step: 239000, Movement, signal: -1.966e-01 0.000e+00 8.648e-01
# Step: 240000, Movement, signal: -6.606e-01 0.000e+00 9.978e-01
# Step: 241000, Movement, signal: -5.382e+00 0.000e+00 8.592e-01
# Step: 242000, Movement, signal: -1.585e+00 0.000e+00 8.551e-01
# Step: 243000, Movement, signal: 4.005e+00 0.000e+00 8.638e-01
# Step: 244000, Movement, signal: -5.206e+00 0.000e+00 9.437e-01
# Step: 245000, Movement, signal: -5.906e-01 0.000e+00 9.559e-01
# Step: 246000, Movement, signal: -5.649e+00 0.000e+00 7.599e-01
# Step: 247000, Movement, signal: -8.019e-01 0.000e+00 9.732e-01
# Step: 248000, Movement, signal: -3.537e+00 0.000e+00 8.709e-01
# Step: 249000, Movement, signal: 1.190e+00 0.000e+00 1.031e+00
# Step: 250000, Movement, signal: -4.666e-01 0.000e+00 8.787e-01
# Step: 251000, Movement, signal: 1.573e+00 0.000e+00 9.607e-01
# Step: 252000, Movement, signal: 6.369e-01 0.000e+00 9.679e-01
# Step: 253000, Movement, signal: -2.766e-02 0.000e+00 9.062e-01
# Step: 254000, Movement, signal: -3.244e+00 0.000e+00 7.659e-01
# Step: 255000, Movement, signal: 3.338e-01 0.000e+00 9.529e-01
# Step: 256000, Movement, signal: 3.379e+00 0.000e+00 1.021e+00
# Step: 257000, Movement, signal: 1.758e-01 0.000e+00 9.404e-01
# Step: 258000, Movement, signal: 2.812e-01 0.000e+00 8.544e-01
# Step: 259000, Movement, signal: 2.017e-01 0.000e+00 8.094e-01
# Step: 260000, Movement, signal: -6.618e-01 0.000e+00 8.969e-01
# Step: 261000, Movement, signal: 7.153e-02 0.000e+00 9.437e-01
# Step: 262000, Movement, signal: -5.307e-01 0.000e+00 9.114e-01
# Step: 263000, Movement, signal: 9.842e-01 0.000e+00 9.104e-01
# Step: 264000, Movement, signal: -9.951e-01 0.000e+00 9.236e-01
# Step: 265000, Movement, signal: 1.121e+00 0.000e+00 9.321e-01
# Step: 266000, Movement, signal: 1.533e+00 0.000e+00 9.606e-01
# Step: 267000, Movement, signal: 2.585e-01 0.000e+00 7.541e-01
# Step: 268000, Movement, signal: 7.505e-01 0.000e+00 9.300e-01
# Step: 269000, Movement, signal: -3.472e-01 0.000e+00 8.789e-01
# Step: 270000, Movement, signal: 2.524e-01 0.000e+00 9.091e-01
# Step: 271000, Movement, signal: -1.384e+00 0.000e+00 9.353e-01
# Step: 272000, Movement, signal: -6.730e-01 0.000e+00 8.617e-01
# Step: 273000, Movement, signal: 2.040e+00 0.000e+00 8.608e-01
# Step: 274000, Movement, signal: 1.192e-01 0.000e+00 8.518e-01
# Step: 275000, Movement, signal: -2.035e+00 0.000e+00 9.101e-01
# Step: 276000, Movement, signal: -1.959e+00 0.000e+00 9.581e-01
# Step: 277000, Movement, signal: -5.518e-01 0.000e+00 9.495e-01
# Step: 278000, Movement, signal: -1.938e+00 0.000e+00 9.628e-01
# Step: 279000, Movement, signal: -5.767e-01 0.000e+00 9.040e-01
# Step: 280000, Movement, signal: -4.564e-01 0.000e+00 1.016e+00
# Step: 281000, Movement, signal: 4.472e-01 0.000e+00 9.600e-01
# Step: 282000, Movement, signal: 1.148e-01 0.000e+00 9.750e-01
# Step: 283000, Movement, signal: 4.666e-02 0.000e+00 8.928e-01
# Step: 284000, Movement, signal: 7.034e-01 0.000e+00 8.299e-01
# Step: 285000, Movement, signal: 7.679e-01 0.000e+00 8.713e-01
# Step: 286000, Movement, signal: 3.684e+00 0.000e+00 7.966e-01
# Step: 287000, Movement, signal: -2.061e+00 0.000e+00 9.615e-01
# Step: 288000, Movement, signal: -1.364e+00 0.000e+00 9.646e-01
# Step: 289000, Movement, signal: -4.151e-01 0.000e+00 9.897e-01
# Step: 290000, Movement, signal: 4.249e-01 0.000e+00 9.801e-01
# Step: 291000, Movement, signal: 1.095e+00 0.000e+00 1.019e+00
# Step: 292000, Movement, signal: 2.490e+00 0.000e+00 7.970e-01
# Step: 293000, Movement, signal: -2.390e-01 0.000e+00 9.769e-01
# Step: 294000, Movement, signal: 7.932e-01 0.000e+00 8.716e-01
# Step: 295000, Movement, signal: -1.822e+00 0.000e+00 9.819e-01
# Step: 296000, Movement, signal: 1.805e+00 0.000e+00 9.910e-01
# Step: 297000, Movement, signal: -1.286e+00 0.000e+00 9.976e-01
# Step: 298000, Movement, signal: -2.676e+00 0.000e+00 8.574e-01
# Step: 299000, Movement, signal: -3.767e+00 0.000e+00 9.801e-01
# Step: 300000, Movement, signal: 8.002e-01 0.000e+00 9.223e-01
# Step: 301000, Movement, signal: 1.782e-01 0.000e+00 1.017e+00
# Step: 302000, Movement, signal: -4.814e-01 0.000e+00 8.444e-01
# Step: 303000, Movement, signal: -3.342e+00 0.000e+00 9.321e-01
# Step: 304000, Movement, signal: -2.353e-01 0.000e+00 9.902e-01
# Step: 305000, Movement, signal: 4.110e+00 0.000e+00 8.620e-01
# Step: 306000, Movement, signal: -4.069e+00 0.000e+00 9.718e-01
# Step: 307000, Movement, signal: -1.425e+00 0.000e+00 9.094e-01
# Step: 308000, Movement, signal: -2.032e+00 0.000e+00 8.509e-01
# Step: 309000, Movement, signal: -1.227e+00 0.000e+00 8.997e-01
# Step: 310000, Movement, signal: 8.009e-03 0.000e+00 9.651e-01
# Step: 311000, Movement, signal: 1.146e-01 0.000e+00 9.501e-01
# Step: 312000, Movement, signal: -4.830e+00 0.000e+00 9.801e-01
# Step: 313000, Movement, signal: 1.832e-01 0.000e+00 7.552e-01
# Step: 314000, Movement, signal: -5.074e-01 0.000e+00 9.901e-01
# Step: 315000, Movement, signal: -2.753e+00 0.000e+00 8.135e-01
# Step: 316000, Movement, signal: 2.350e-01 0.000e+00 1.005e+00
# Step: 317000, Movement, signal: -3.199e+00 0.000e+00 8.663e-01
# Step: 318000, Movement, signal: -1.231e+00 0.000e+00 9.415e-01
# Step: 319000, Movement, signal: 8.759e-01 0.000e+00 9.474e-01
# Step: 320000, Movement, signal: -6.904e-01 0.000e+00 1.005e+00
# Step: 321000, Movement, signal: 7.998e-02 0.000e+00 8.878e-01
# Step: 322000, Movement, signal: -1.902e+00 0.000e+00 7.184e-01
# Step: 323000, Movement, signal: -6.191e+00 0.000e+00 9.686e-01
# Step: 324000, Movement, signal: -5.626e-01 0.000e+00 9.084e-01
# Step: 325000, Movement, signal: -1.974e+00 0.000e+00 9.577e-01
# Step: 326000, Movement, signal: 4.903e-01 0.000e+00 8.227e-01
# Step: 327000, Movement, signal: -4.289e-01 0.000e+00 9.536e-01
# Step: 328000, Movement, signal: -1.032e-01 0.000e+00 8.688e-01
# Step: 329000, Movement, signal: 3.292e-01 0.000e+00 8.880e-01
# Step: 330000, Movement, signal: 5.078e+00 0.000e+00 7.998e-01
# Step: 331000, Movement, signal: -4.216e+00 0.000e+00 9.811e-01
# Step: 332000, Movement, signal: -1.407e+00 0.000e+00 9.209e-01
# Step: 333000, Movement, signal: 5.467e-01 0.000e+00 9.612e-01
# Step: 334000, Movement, signal: -1.279e+00 0.000e+00 8.920e-01
# Step: 335000, Movement, signal: -1.595e+00 0.000e+00 8.372e-01
# Step: 336000, Movement, signal: 1.385e-01 0.000e+00 8.146e-01
# Step: 337000, Movement, signal: -2.608e-01 0.000e+00 8.512e-01
# Step: 338000, Movement, signal: -1.480e+00 0.000e+00 9.064e-01
# Step: 339000, Movement, signal: -5.764e-01 0.000e+00 8.067e-01
# Step: 340000, Movement, signal: -3.428e+00 0.000e+00 9.395e-01
# Step: 341000, Movement, signal: -3.800e-01 0.000e+00 8.275e-01
# Step: 342000, Movement, signal: 4.746e+00 0.000e+00 8.785e-01
# Step: 343000, Movement, signal: -2.889e+00 0.000e+00 7.535e-01
# Step: 344000, Movement, signal: -2.483e-01 0.000e+00 8.340e-01
# Step: 345000, Movement, signal: 1.681e+00 0.000e+00 9.098e-01
# Step: 346000, Movement, signal: 1.030e+00 0.000e+00 8.815e-01
# Step: 347000, Movement, signal: -6.362e-01 0.000e+00 9.091e-01
# Step: 348000, Movement, signal: -3.364e+00 0.000e+00 8.471e-01
# Step: 349000, Movement, signal: -2.519e+00 0.000e+00 9.198e-01
# Step: 350000, Movement, signal: 1.284e+00 0.000e+00 8.859e-01
# Step: 351000, Movement, signal: 1.231e-01 0.000e+00 9.406e-01
# Step: 352000, Movement, signal: -1.237e-01 0.000e+00 7.678e-01
# Step: 353000, Movement, signal: -4.320e-01 0.000e+00 9.285e-01
# Step: 354000, Movement, signal: -9.647e-01 0.000e+00 6.686e-01
# Step: 355000, Movement, signal: -3.371e-01 0.000e+00 8.405e-01
# Step: 356000, Movement, signal: -1.825e+00 0.000e+00 8.018e-01
# Step: 357000, Movement, signal: -7.726e-02 0.000e+00 7.206e-01
# Step: 358000, Movement, signal: 3.702e-01 0.000e+00 9.043e-01
# Step: 359000, Movement, signal: -3.992e-01 0.000e+00 9.716e-01
# Step: 360000, Movement, signal: -6.702e-01 0.000e+00 8.790e-01
# Step: 361000, Movement, signal: -3.865e+00 0.000e+00 1.014e+00
# Step: 362000, Movement, signal: -3.823e+00 0.000e+00 9.564e-01
# Step: 363000, Movement, signal: 8.969e-01 0.000e+00 9.107e-01
# Step: 364000, Movement, signal: 4.286e-01 0.000e+00 1.040e+00
# Step: 365000, Movement, signal: 6.753e-01 0.000e+00 9.343e-01
# Step: 366000, Movement, signal: -2.160e-01 0.000e+00 8.869e-01
# Step: 367000, Movement, signal: -2.019e-02 0.000e+00 9.135e-01
# Step: 368000, Movement, signal: -1.041e-01 0.000e+00 8.529e-01
# Step: 369000, Movement, signal: 5.750e-02 0.000e+00 8.602e-01
# Step: 370000, Movement, signal: 1.118e-01 0.000e+00 1.014e+00
# Step: 371000, Movement, signal: -4.716e-01 0.000e+00 9.170e-01
# Step: 372000, Movement, signal: 6.443e-01 0.000e+00 9.628e-01
# Step: 373000, Movement, signal: 1.850e-01 0.000e+00 1.011e+00
# Step: 374000, Movement, signal: -3.989e+00 0.000e+00 9.067e-01
# Step: 375000, Movement, signal: 7.143e-01 0.000e+00 9.763e-01
# Step: 376000, Movement, signal: 2.645e+00 0.000e+00 8.873e-01
# Step: 377000, Movement, signal: -2.755e+00 0.000e+00 7.056e-01
# Step: 378000, Movement, signal: -5.996e+00 0.000e+00 9.213e-01
# Step: 379000, Movement, signal: -9.029e-01 0.000e+00 9.576e-01
# Step: 380000, Movement, signal: -1.331e-01 0.000e+00 1.013e+00
# Step: 381000, Movement, signal: 1.960e-01 0.000e+00 7.163e-01
# Step: 382000, Movement, signal: 9.913e-01 0.000e+00 9.585e-01
# Step: 383000, Movement, signal: 3.890e+00 0.000e+00 9.356e-01
# Step: 384000, Movement, signal: -1.520e+00 0.000e+00 9.231e-01
# Step: 385000, Movement, signal: -1.147e+00 0.000e+00 9.689e-01
# Step: 386000, Movement, signal: -5.754e+00 0.000e+00 9.484e-01
# Step: 387000, Movement, signal: 4.233e-01 0.000e+00 1.003e+00
# Step: 388000, Movement, signal: -8.669e-02 0.000e+00 9.578e-01
# Step: 389000, Movement, signal: 1.815e+00 0.000e+00 9.169e-01
# Step: 390000, Movement, signal: -1.171e-01 0.000e+00 9.031e-01
# Step: 391000, Movement, signal: -1.867e-01 0.000e+00 9.046e-01
# Step: 392000, Movement, signal: 1.215e+00 0.000e+00 1.012e+00
# Step: 393000, Movement, signal: 5.932e-01 0.000e+00 9.442e-01
# Step: 394000, Movement, signal: 3.073e-01 0.000e+00 8.730e-01
# Step: 395000, Movement, signal: -1.167e+00 0.000e+00 8.807e-01
# Step: 396000, Movement, signal: 9.232e-02 0.000e+00 8.495e-01
# Step: 397000, Movement, signal: -4.552e-01 0.000e+00 8.461e-01
# Step: 398000, Movement, signal: -3.539e-01 0.000e+00 8.928e-01
# Step: 399000, Movement, signal: 6.025e-01 0.000e+00 7.944e-01

# %%
src_track = []
for i in range(0, istop, 100): # for each position of the beam
    guess_i_x = np.where(generate_sig(i, 15)==generate_sig(i, 15).max())[1][0] # at t = 0, this is where the emitter is
    guess_i_y = np.where(generate_sig(i, 15)==generate_sig(i, 15).max())[0][0] # at t = 0, this is where the emitter is
#     src_track.append([(np.abs(xx - xr[i])).argmin(), (np.abs(yy - yr[i])).argmin()])
    src_track.append([guess_i_x, guess_i_y])
src_track = np.array(src_track, dtype = float)
src_track.shape
# Out:
# (4000, 2)

# %%
plt.plot(xtrack_arr[:,0], xtrack_arr[:,1], c='r')
plt.plot(src_track[:, 0], src_track[:, 1], c='b')
plt.plot(xtrack_arr[0,0], xtrack_arr[0,1], marker='x',c='k')
plt.plot(xtrack_arr[100,0], xtrack_arr[100,1], marker='x',c='g')
plt.xlim(0, 5 * gridMax + 1)
plt.ylim(0, 5 * gridMax + 1)
plt.show()

# %%
fig, ax1 = plt.subplots(figsize = (18, 12))

color = 'k'
ax1.set_ylabel('Tracking Error', color=color)  # we already handled the x-label with ax1
poserr = src_xtrack - xtrack_arr
plt.plot(t[istart::istep], poserr, color = 'c', label = "Beam position error")
ax1.tick_params(axis='y', labelcolor=color)
ax1.set_ylim(-gridMax, gridMax)
ax1.grid()
ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis

color = 'tab:red'
ax2.set_xlabel('Time (s)')
ax2.set_ylabel('Beam Positions', color=color)
plt.plot(t[istart::istep], xtrack_arr, color = 'b', label = "Tracked beam maximum position")
plt.plot(t[istart::istep], src_xtrack, color = 'r', label = "Real beam maximum position")
ax2.tick_params(axis='y', labelcolor=color)

fig.tight_layout()  # otherwise the right y-label is slightly clipped
plt.show()

# %%
srcpos_f = np.fft.fftshift(np.fft.fft(src_xtrack))
mespos_f = np.fft.fftshift(np.fft.fft(xtrack_arr))
k_ax = np.fft.fftshift(np.fft.fftfreq(srcpos_f.shape[0]))
plt.figure(figsize = (18, 12))
plt.plot(k_ax, np.arctan2(srcpos_f.imag, srcpos_f.real), label = "Source position FFT Phase", color = 'r', marker = 'o', ls = '')
plt.plot(k_ax, np.arctan2(mespos_f.imag, mespos_f.real), label = "Measured position FFT Phase", color = 'b', marker = 'x')
plt.grid()
plt.legend()
plt.xlim(0, 100/100000)

# %%
plt.figure(figsize = (18, 12))
plt.plot(k_ax, np.arctan2(srcpos_f.imag, srcpos_f.real) - np.arctan2(mespos_f.imag, mespos_f.real), label = "FFT Phase Difference", color = 'r', marker = 'x')
plt.axhline(0)
plt.grid()
plt.legend()
plt.xlim(0, 30/100000)

# %%
fig, ax1 = plt.subplots(figsize = (18, 12))

color = 'k'
ax1.set_ylabel('Tracking Error', color=color)  # we already handled the x-label with ax1
poserr = src_xtrack - xtrack_arr
plt.plot(t[istart::istep], poserr, color = 'c', label = "Beam position error")
ax1.tick_params(axis='y', labelcolor=color)
ax1.set_ylim(-gridMax, gridMax)
ax1.grid()
ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis

color = 'tab:red'
ax2.set_xlabel('Time (s)')
ax2.set_ylabel('Beam Positions', color=color)
plt.plot(t[istart::istep], xtrack_arr, color = 'b', label = "Tracked beam maximum position")
plt.plot(t[istart::istep], src_xtrack, color = 'r', label = "Real beam maximum position")
ax2.tick_params(axis='y', labelcolor=color)

fig.tight_layout()  # otherwise the right y-label is slightly clipped
plt.show()
